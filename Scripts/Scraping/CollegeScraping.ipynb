# %%
import requests
from bs4 import BeautifulSoup, Comment
import pandas as pd
import time
import numpy as np

# %%
#Gathering players that participated in combine
firstLast=[]

dfNames = pd.read_csv("FilteredTestData.csv") #FilteredTestData is players that don't overlap

names = dfNames["PLAYER"]

for i in names:
    j=i.split()
    if len(j) ==2:
        firstLast.append([j[0].lower().replace(".",""),j[1].lower()])
print(firstLast)
# Out:
# [['aj', 'lawson'], ['aj', 'green'], ['aj', 'griffin'], ['aj', 'johnson'], ['aaron', 'nesmith'], ['aaron', 'wiggins'], ['adam', 'flagler'], ['adem', 'bona'], ['ajay', 'mitchell'], ['aleksej', 'pokusevski'], ['alex', 'ducas'], ['alex', 'sarr'], ['alize', 'johnson'], ['alperen', 'sengun'], ['amen', 'thompson'], ['amir', 'coffey'], ['andrew', 'nembhard'], ['anthony', 'black'], ['anthony', 'edwards'], ['anthony', 'gill'], ['anthony', 'lamb'], ['antonio', 'reeves'], ['ariel', 'hukporti'], ['armoni', 'brooks'], ['ausar', 'thompson'], ['austin', 'reaves'], ['ayo', 'dosunmu'], ['baylor', 'scheierman'], ['ben', 'sheppard'], ['bennedict', 'mathurin'], ['bilal', 'coulibaly'], ['blake', 'wesley'], ['bol', 'bol'], ['bones', 'hyland'], ['branden', 'carlson'], ['brandin', 'podziemski'], ['brandon', 'boston'], ['brandon', 'miller'], ['brandon', 'williams'], ['braxton', 'key'], ['brice', 'sensabaugh'], ['brodric', 'thomas'], ['bronny', 'james'], ['bryce', 'mcgowens'], ['bub', 'carrington'], ['cj', 'elleby'], ['cade', 'cunningham'], ['caleb', 'houstan'], ['caleb', 'martin'], ['cam', 'spencer'], ['cam', 'thomas'], ['cam', 'whitmore'], ['cason', 'wallace'], ['cassius', 'stanley'], ['cassius', 'winston'], ['charles', 'bassey'], ['chet', 'holmgren'], ['chris', 'duarte'], ['chris', 'livingston'], ['christian', 'braun'], ['christian', 'koloko'], ['chuma', 'okeke'], ['cody', 'williams'], ['colby', 'jones'], ['cole', 'anthony'], ['colin', 'castleton'], ['collin', 'gillespie'], ['corey', 'kispert'], ['daquan', 'jeffries'], ['daishen', 'nix'], ['dalano', 'banton'], ['dalen', 'terry'], ['dalton', 'knecht'], ['daniel', 'oturu'], ['dariq', 'whitehead'], ['david', 'roddy'], ['davion', 'mitchell'], ["day'ron", 'sharpe'], ['dean', 'wade'], ['deividas', 'sirvydis'], ['deni', 'avdija'], ['desmond', 'bane'], ['devin', 'carter'], ['devin', 'vassell'], ['devontae', 'cacok'], ['dillon', 'jones'], ['dominick', 'barlow'], ['donovan', 'clingan'], ['drew', 'peterson'], ['duop', 'reath'], ['dylan', 'windler'], ['dyson', 'daniels'], ['elijah', 'hughes'], ['enrique', 'freeman'], ['eugene', 'omoruyi'], ['evan', 'mobley'], ['facundo', 'campazzo'], ['franz', 'wagner'], ['freddie', 'gillespie'], ['gg', 'jackson'], ['gabe', 'vincent'], ['garrison', 'mathews'], ['gradey', 'dick'], ['gui', 'santos'], ['haywood', 'highsmith'], ['herbert', 'jones'], ['hunter', 'tyson'], ['ibou', 'badji'], ['ignas', 'brazdeikis'], ['immanuel', 'quickley'], ['isaac', 'jones'], ['isaac', 'okoro'], ['isaiah', 'collier'], ['isaiah', 'jackson'], ['isaiah', 'joe'], ['isaiah', 'livers'], ['isaiah', 'roby'], ['isaiah', 'stewart'], ['isaiah', 'wong'], ['ish', 'wainright'], ['jt', 'thor'], ["ja'kobe", 'walter'], ['jabari', 'walker'], ['jacob', 'gilyard'], ['jaden', 'hardy'], ['jaden', 'ivey'], ['jaden', 'mcdaniels'], ['jaden', 'springer'], ["jae'sean", 'tate'], ['jake', 'laravia'], ['jalen', 'duren'], ['jalen', 'green'], ['jalen', 'hood-schifino'], ['jalen', 'johnson'], ['jalen', 'mcdaniels'], ['jalen', 'pickett'], ['jalen', 'smith'], ['jalen', 'suggs'], ['jalen', 'williams'], ['jalen', 'wilson'], ['jamal', 'cain'], ['jamal', 'shead'], ['james', 'bouknight'], ['james', 'wiseman'], ['jamison', 'battle'], ['jarace', 'walker'], ['jared', 'butler'], ['jared', 'mccain'], ['jarred', 'vanderbilt'], ['jarrell', 'brantley'], ['javon', 'freeman-liberty'], ['jay', 'huff'], ['jaylen', 'clark'], ['jaylen', 'nowell'], ['jaylen', 'wells'], ['jaylin', 'williams'], ['jaylon', 'tyson'], ['jeremiah', 'robinson-earl'], ['jeremy', 'sochan'], ['jericho', 'sims'], ['jett', 'howard'], ['jock', 'landale'], ['joe', 'wieskamp'], ['john', 'konchar'], ['johnny', 'davis'], ['johnny', 'furphy'], ['johnny', 'juzang'], ['jonathan', 'kuminga'], ['jonathan', 'mogbo'], ['jontay', 'porter'], ['jordan', 'goodwin'], ['jordan', 'hawkins'], ['jordan', 'miller'], ['jordan', 'nwora'], ['jordan', 'walsh'], ['jose', 'alvarado'], ['josh', 'christopher'], ['josh', 'giddey'], ['josh', 'green'], ['josh', 'hall'], ['josh', 'minott'], ['joshua', 'primo'], ['ju ...

# %% [markdown]
# Shortened version of code to go over the first 4 rows of combine participants, Full code took hours and was run in VSCode. This also filters out the international players that did not play in college.

# %%
###GPT Test code

df2 = pd.DataFrame()
count=0

for i in firstLast:
    cont = True
    url = f'https://www.sports-reference.com/cbb/players/{i[0]}-{i[1]}-1.html'
    page = requests.get(url).text
    soup = BeautifulSoup(page, 'html.parser')
    table = soup.find('table', id='players_per_game')

    # Look in comments if table is hidden
    if table is None:
        comments = soup.find_all(string=lambda text: isinstance(text, Comment))
        for comment in comments:
            if 'id="players_per_game"' in comment:
                comment_soup = BeautifulSoup(comment, 'html.parser')
                table = comment_soup.find('table', id='players_per_game')
                if table:
                    break

    if table is None:
        print("(no college stats table found)")
        continue  # skip this player

    # Read table into df
    df = pd.read_html(str(table))[0]

    # Drop completely empty rows
    df = df.dropna(how="all")

                            #ChatGPT
    # -------  KEY PART: keep only the Career row ------- #
    # Most cbb tables have a "Season" column with 'Career' in it
    if 'Season' in df.columns:
        career = df[df['Season'] == 'Career']
    else:
        # fallback: assume last row is career totals
        career = df.tail(1)
    # ----------------------------------------------------- #

    if career.empty:
        continue

    # Add name and append
    career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
    df2 = pd.concat([df2, career], ignore_index=True)

    lag = np.random.uniform(low=5, high=15)
    print(f'...waiting {round(lag, 1)} seconds')
    time.sleep(lag)
    count += 1
df2
# Out:
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 8.6 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 9.5 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.7 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 14.2 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 11.1 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 12.1 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 11.7 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 5.3 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 9.3 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.1 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 14.4 seconds
# (no college stats table found)
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.1 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 13.2 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 5.6 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 11.5 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 7.4 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 8.3 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 14.4 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 9.2 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 10.2 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.7 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 5.4 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 11.2 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 9.8 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.1 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 8.1 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 12.2 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 11.0 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 10.7 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 5.5 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 12.5 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 9.9 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 10.9 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 14.4 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 10.0 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 7.4 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 10.3 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 10.1 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 14.9 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 8.6 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 9.0 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.1 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 8.5 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.5 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 14.3 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 9.3 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.3 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 13.7 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.6 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.9 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 10.4 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 10.6 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 10.2 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 7.2 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.9 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 12.4 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 12.3 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 14.1 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 5.7 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 7.5 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 7.1 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.5 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 13.5 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 11.9 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 12.8 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 13.0 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 5.5 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 14.4 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 14.3 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 9.2 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 5.5 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 13.3 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 13.4 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 11.1 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 13.3 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 14.5 seconds
# (no college stats table found)
# (no college stats table found)
# (no college stats table found)
# (no college stats table found)
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 11.8 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 13.7 seconds
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.0 seconds
# (no college stats table found)
# (no college stats table found)
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 10.3 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 6.1 seconds
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:28: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# /var/folders/5h/_7p0899150l8hd4khcp86lf00000gn/T/ipykernel_62835/3377003055.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career["Name"] = i[0].capitalize() + ' ' + i[1].capitalize()
# ...waiting 8.6 seconds
#      Season    Team    Conf   Class  Pos    G   GS    MP   FG   FGA  ...  DRB  \
# 0    Career  Career  Career  Career  NaN  151  118  25.7  4.0   9.2  ...  3.2
# 1    Career  Career  Career  Career  NaN   99   99  33.7  5.9  14.4  ...  3.0
# 2    Career  Career  Career  Career  NaN   39   25  24.0  3.7   7.6  ...  3.2
# 3    Career  Career  Career  Career  NaN  116   99  24.3  2.4   6.7  ...  2.0
# 4    Career  Career  Career  Career  NaN   46   33  31.0  4.8  10.8  ...  4.3
# ..      ...     ...     ...     ...  ...  ...  ...   ...  ...   ...  ...  ...
# 260  Career  Career  Career  Career  NaN  105   45  21.3  3.3   5.7  ...  4.6
# 261  Career  Career  Career  Career  NaN  134  107  30.1  3.8   8.9  ...  3.4
# 262  Career  Career  Career  Career  NaN  138  108  24.9  6.7  10.8  ...  5.7
# 263  Career  Career  Career  Career  NaN   32   32  30.7  5.6   9.8  ...  5.5
# 264  Career  Career  Career  Career  NaN   20   14  27.9  3.8  10.2  ...  4.1
#
#      TRB  AST  STL  BLK  TOV   PF   PTS Awards             Name
# 0    4.3  2.7  0.8  0.2  2.5  2.6  10.6    NaN        Aj Lawson
# 1    3.3  2.6  0.7  0.1  2.7  1.7  17.9    NaN         Aj Green
# 2    3.9  1.0  0.5  0.6  0.6  1.1  10.4    NaN       Aj Griffin
# 3    2.4  2.0  1.4  0.1  2.7  2.6   7.0    NaN       Aj Johnson
# 4    5.3  1.3  0.9  0.7  1.6  3.0  14.7    NaN    Aaron Nesmith
# ..   ...  ...  ...  ...  ...  ...   ...    ...              ...
# 260  6.6  1.6  0.8  1.5  1.3  2.2   8.7    NaN   Xavier Tillman
# 261  4.5  1.5  0.7  1.1  1.3  1.8  10.9    NaN    Yuta Watanabe
# 262  9.6  1.3  0.2  1.7  1.9  2.0  18.2    NaN        Zach Edey
# 263  8.6  0.8  0.7  0.9  2.2  2.4  16.1    NaN       Zeke Nnaji
# 264  4.6  2.2  0.9  0.6  2.9  2.4  10.7    NaN  Ziaire Williams
#
# [265 rows x 32 columns]

# %%
#Filter out irrelivant stats to quick clean. Also only career stats
df_new = df2.drop(columns=(["Season","Team","Conf","Class","Pos","Awards"]))
df_new
# Out:
#        G   GS    MP   FG   FGA    FG%   3P  3PA    3P%   2P  ...  ORB  DRB  \
# 0    151  118  25.7  4.0   9.2   .440  0.6  2.1   .291  3.4  ...  1.2  3.2
# 1     99   99  33.7  5.9  14.4  0.414  2.7  7.1  0.378  3.3  ...  0.3  3.0
# 2     39   25  24.0  3.7   7.6  0.493  1.8  4.1  0.447  1.9  ...  0.8  3.2
# 3    116   99  24.3  2.4   6.7  0.356  1.1  3.6  0.301  1.3  ...  0.4  2.0
# 4     46   33  31.0  4.8  10.8  0.442  2.6  6.3   0.41  2.2  ...  1.0  4.3
# ..   ...  ...   ...  ...   ...    ...  ...  ...    ...  ...  ...  ...  ...
# 260  105   45  21.3  3.3   5.7  0.582  0.2  0.7  0.273  3.1  ...  2.0  4.6
# 261  134  107  30.1  3.8   8.9  0.425  1.2  3.5  0.337  2.6  ...  1.1  3.4
# 262  138  108  24.9  6.7  10.8  0.621  0.0  0.0    0.5  6.7  ...  3.9  5.7
# 263   32   32  30.7  5.6   9.8   0.57  0.2  0.5  0.294  5.4  ...  3.1  5.5
# 264   20   14  27.9  3.8  10.2  0.374  1.2  4.0  0.291  2.7  ...  0.5  4.1
#
#      TRB  AST  STL  BLK  TOV   PF   PTS             Name
# 0    4.3  2.7  0.8  0.2  2.5  2.6  10.6        Aj Lawson
# 1    3.3  2.6  0.7  0.1  2.7  1.7  17.9         Aj Green
# 2    3.9  1.0  0.5  0.6  0.6  1.1  10.4       Aj Griffin
# 3    2.4  2.0  1.4  0.1  2.7  2.6   7.0       Aj Johnson
# 4    5.3  1.3  0.9  0.7  1.6  3.0  14.7    Aaron Nesmith
# ..   ...  ...  ...  ...  ...  ...   ...              ...
# 260  6.6  1.6  0.8  1.5  1.3  2.2   8.7   Xavier Tillman
# 261  4.5  1.5  0.7  1.1  1.3  1.8  10.9    Yuta Watanabe
# 262  9.6  1.3  0.2  1.7  1.9  2.0  18.2        Zach Edey
# 263  8.6  0.8  0.7  0.9  2.2  2.4  16.1       Zeke Nnaji
# 264  4.6  2.2  0.9  0.6  2.9  2.4  10.7  Ziaire Williams
#
# [265 rows x 26 columns]

# %%
df_new.to_csv("NCAA_2020_2025.csv",index=False)
df_new
# Out:
#        G   GS    MP   FG   FGA    FG%   3P  3PA    3P%   2P  ...  ORB  DRB  \
# 0    151  118  25.7  4.0   9.2   .440  0.6  2.1   .291  3.4  ...  1.2  3.2
# 1     99   99  33.7  5.9  14.4  0.414  2.7  7.1  0.378  3.3  ...  0.3  3.0
# 2     39   25  24.0  3.7   7.6  0.493  1.8  4.1  0.447  1.9  ...  0.8  3.2
# 3    116   99  24.3  2.4   6.7  0.356  1.1  3.6  0.301  1.3  ...  0.4  2.0
# 4     46   33  31.0  4.8  10.8  0.442  2.6  6.3   0.41  2.2  ...  1.0  4.3
# ..   ...  ...   ...  ...   ...    ...  ...  ...    ...  ...  ...  ...  ...
# 260  105   45  21.3  3.3   5.7  0.582  0.2  0.7  0.273  3.1  ...  2.0  4.6
# 261  134  107  30.1  3.8   8.9  0.425  1.2  3.5  0.337  2.6  ...  1.1  3.4
# 262  138  108  24.9  6.7  10.8  0.621  0.0  0.0    0.5  6.7  ...  3.9  5.7
# 263   32   32  30.7  5.6   9.8   0.57  0.2  0.5  0.294  5.4  ...  3.1  5.5
# 264   20   14  27.9  3.8  10.2  0.374  1.2  4.0  0.291  2.7  ...  0.5  4.1
#
#      TRB  AST  STL  BLK  TOV   PF   PTS             Name
# 0    4.3  2.7  0.8  0.2  2.5  2.6  10.6        Aj Lawson
# 1    3.3  2.6  0.7  0.1  2.7  1.7  17.9         Aj Green
# 2    3.9  1.0  0.5  0.6  0.6  1.1  10.4       Aj Griffin
# 3    2.4  2.0  1.4  0.1  2.7  2.6   7.0       Aj Johnson
# 4    5.3  1.3  0.9  0.7  1.6  3.0  14.7    Aaron Nesmith
# ..   ...  ...  ...  ...  ...  ...   ...              ...
# 260  6.6  1.6  0.8  1.5  1.3  2.2   8.7   Xavier Tillman
# 261  4.5  1.5  0.7  1.1  1.3  1.8  10.9    Yuta Watanabe
# 262  9.6  1.3  0.2  1.7  1.9  2.0  18.2        Zach Edey
# 263  8.6  0.8  0.7  0.9  2.2  2.4  16.1       Zeke Nnaji
# 264  4.6  2.2  0.9  0.6  2.9  2.4  10.7  Ziaire Williams
#
# [265 rows x 26 columns]
